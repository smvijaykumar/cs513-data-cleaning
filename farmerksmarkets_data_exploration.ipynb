# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
farmersmkt = pd.read_csv('farmersmarkets.csv')

# %%
farmersmkt.head()
# Out:
#       FMID                                        MarketName  \
# 0  1012063   Caledonia Farmers Market Association - Danville
# 1  1011871                 Stearns Homestead Farmers' Market
# 2  1011878                                   100 Mile Market
# 3  1009364                 106 S. Main Street Farmers Market
# 4  1010691               10th Steet Community Farmers Market
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                        http://Stearnshomestead.com
# 2                          http://www.pfcmarkets.com
# 3             http://thetownofsixmile.wordpress.com/
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                                                NaN     NaN     NaN
# ...

# %%
farmersmkt.describe()
# Out:
#                FMID            x            y
# count  8.675000e+03  8646.000000  8646.000000
# mean   1.009420e+06   -90.955082    39.167766
# std    5.548042e+04    17.488990     5.288960
# min    1.000001e+06  -166.540000    17.709900
# 25%    1.003090e+06   -97.278250    36.296148
# 50%    1.006213e+06   -86.208287    40.051682
# 75%    1.009568e+06   -77.522151    42.447858
# max    2.000036e+06   -64.704300    64.862750

# %%
farmersmkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8675 entries, 0 to 8674
# Data columns (total 59 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FMID           8675 non-null   int64
#  1   MarketName     8675 non-null   object
#  2   Website        5209 non-null   object
#  3   Facebook       3793 non-null   object
#  4   Twitter        996 non-null    object
#  5   Youtube        159 non-null    object
#  6   OtherMedia     634 non-null    object
#  7   street         8390 non-null   object
#  8   city           8634 non-null   object
#  9   County         8135 non-null   object
#  10  State          8675 non-null   object
#  11  zip            7727 non-null   object
#  12  Season1Date    5377 non-null   object
#  13  Season1Time    5522 non-null   object
#  14  Season2Date    430 non-null    object
#  15  Season2Time    415 non-null    object
#  16  Season3Date    79 non-null     object
# ...

# %%
farmersmkt.nunique()
# Out:
# FMID             8675
# MarketName       8102
# Website          4273
# Facebook         3347
# Twitter           748
# Youtube           122
# OtherMedia        495
# street           8196
# city             5012
# County           1490
# State              53
# zip              6277
# Season1Date      2359
# Season1Time      1700
# Season2Date       378
# Season2Time       205
# Season3Date        77
# Season3Time        45
# Season4Date         6
# Season4Time         6
# x                8533
# y                8533
# Location           10
# Credit              2
# WIC                 2
# WICcash             2
# SFMNP               2
# SNAP                2
# Organic             3
# Bakedgoods          2
# Cheese              2
# Crafts              2
# Flowers             2
# Eggs                2
# Seafood             2
# Herbs               2
# Vegetables          2
# Honey               2
# Jams                2
# Maple               2
# Meat                2
# ...

# %%
farmersmkt.shape
# Out:
# (8675, 59)

# %%
### Identify columns with too many missing values
for col in farmersmkt.columns:
    percentage_missing = np.mean(farmersmkt[col].isnull())
    print('{} - {}%'.format(col, round(percentage_missing*100)))
# Out:
# FMID - 0%
# MarketName - 0%
# Website - 40%
# Facebook - 56%
# Twitter - 89%
# Youtube - 98%
# OtherMedia - 93%
# street - 3%
# city - 0%
# County - 6%
# State - 0%
# zip - 11%
# Season1Date - 38%
# Season1Time - 36%
# Season2Date - 95%
# Season2Time - 95%
# Season3Date - 99%
# Season3Time - 99%
# Season4Date - 100%
# Season4Time - 100%
# x - 0%
# y - 0%
# Location - 66%
# Credit - 0%
# WIC - 0%
# WICcash - 0%
# SFMNP - 0%
# SNAP - 0%
# Organic - 0%
# Bakedgoods - 0%
# Cheese - 0%
# Crafts - 0%
# Flowers - 0%
# Eggs - 0%
# Seafood - 0%
# Herbs - 0%
# Vegetables - 0%
# Honey - 0%
# Jams - 0%
# Maple - 0%
# Meat - 0%
# Nursery - 0%
# Nuts - 0%
# Plants - 0%
# Poultry - 0%
# Prepared - 0%
# Soap - 0%
# Trees - 0%
# Wine - 0%
# Coffee - 0%
# Beans - 0%
# Fruits - 0%
# Grains - 0%
# Juices - 0%
# Mushrooms - 0%
# PetFood - 0%
# Tofu - 0%
# WildHarvested - 0%
# updateTime - 0%
