# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name below:

# %%
NAME = "Vijayakumar Sitha Mohan"

# %% [markdown]
# ---

# %% [markdown]
# ## Data Cleaning with SQLite in Python Tutorial
# In this part of the assignment, you will learn how to clean your data with SQLite in Python. While SQL is a standardized query language for relational databases, you will likely encounter many different flavors of SQL in your journey as a data scientist. SQLite in Python, for one, is a very popular implementation of SQL that allows you to easily create relational databases and query your data without going through the hassle of understanding everything about database theory.
#
# By the end of this tutorial, you should be able to understand
#
# 1. how to create SQLite tables from existing data files;
# 2. how to write integrity constraints in SQL and check potential violations; and
# 3. how to create a schema for data curation.
#
# Let's get started!

# %%
# Import modules used in this tutorial
import os
import sqlite3

import pandas as pd

# %%
# Remove existing .db files to avoid errors
if os.path.exists('airbnb1.db') == True:
    os.remove('airbnb1.db')

if os.path.exists('airbnb2.db') == True:
    os.remove('airbnb2.db')

# %% [markdown]
# ### TASK 1: DATABASE CREATION
# ##### Description: In this section, you will learn how to build SQLite databases from ```csv``` files. We will first use ```pandas``` to load ```csv``` data files and then show you two ways of creating SQLite databases using the loaded data. These are not the only ways to work with ```csv``` files, and you will likely have many opportunities in the future to decide for yourself which way works best for your own project. The goal here is to help you learn how to create SQLite databases using Python from existing data sources and show you how you can interact with ```sqlite3``` databases using our more user-friendly interface.

# %%
# Create variable for path to data
FILENAME = 'Airbnblistings_dirty_noSpeChar.csv'

# %%
# Load data and view the first ten rows using pandas
df = pd.read_csv(FILENAME)
df[0:10]
# Out:
#       id                                               name  host_id  \
# 0   2384  (Hyde Park - Walk to UChicago/Theological Semi...     2613
# 1   6715                 (Lincoln Park Oasis - Unit 2 ONLY)    15365
# 2   7126              (Tiny Studio Apartment 94 Walk Score)    17928
# 3   9811                    (Barbara's Hideaway - Old Town)    33004
# 4  10610                 (3 Comforts of Cooperative Living)     2140
# 5  10945                            (The Biddle House (#1))    33004
# 6  12068               (Chicago GOLD COAST 1 Bedroom Condo)    40731
# 7  12140                         (Lincoln Park Guest House)    46734
# 8  22362  (*** Luxury in Chicago! 2BR/ 2Ba / Parking / B...    85811
# 9  22651              (beautifully furnished 3 bed/1bath 1)    87231
#
#            host_name  neighbourhood_group    neighbourhood   latitude  \
# 0            Rebecca                  NaN        hyde park  41.788865
# 1               Reem                  NaN            OHARE  41.929262
# 2              Sarah                  NaN        West Town  41.902895
# 3        At Home Inn                  NaN     Lincoln Park  41.917689
# 4        Lois And Ed                  NaN        hyde park  41.797085
# 5        At Home Inn                  NaN     Lincoln Park  41.911827
# 6            Dominic                  NaN  Near North Side  41.904521
# 7  Sharon And Robert                  NaN     Lincoln Park  41.923353
# 8              Craig                  NaN        West Town  41.896168
# 9    Jeff And JoAnne                  NaN        Lake view  41.949105
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0 -87.586709     Private room     50               2                137
# 1 -87.660091  Entire home/apt    255               4                 93
# 2 -87.681822  Entire home/apt     80               2                321
# 3 -87.637879  Entire home/apt    150               3                 33
# 4 -87.591949     Private room     35               2                 31
# 5 -87.639998  Entire home/apt    215               3                  9
# 6 -87.633200  Entire home/apt     99             165                  8
# 7 -87.649510     Private room    289               2                  4
# 8 -87.660411  Entire home/apt     99              60                  9
# 9 -87.657906  Entire home/apt    185               1                174
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0    11/12/18               2.92                               1
# 1     8/12/18               0.81                               2
# 2    10/29/18               2.81                               1
# 3    10/14/18               0.59                               9
# 4     7/29/18               0.63                               5
# 5     11/5/18               0.16                               9
# 6    10/24/17               0.18                               2
# 7    10/17/18               0.10                               1
# 8    10/12/14               0.15                               1
# 9    10/21/18               1.69                              17
#
#    availability_365
# 0               163
# 1               303
# 2               362
# 3               350
# 4               179
# 5               357
# 6               303
# 7               169
# 8               280
# 9                71

# %% [markdown]
# #### TASK 1.1: Interacting with data using ```sqlite3```
# Creating a SQLite database using Python's built-in SQLite module, ```sqlite3```, is probably the most natural way to work with SQLite databases in Python. With the help of ```pandas```, you can easily store an existing ```csv``` data file in a SQLite database without the need to manually enter each row yourself or have your program loop over each instance to achieve the goal, which can be time-consuming.

# %%
# Create database connection and cursor
con_1 = sqlite3.connect('airbnb1.db')
cur_1 = con_1.cursor()

# %%
# Create database table from pandas DataFrame object created earlier
df.to_sql('Listings', con_1)

# %%
# View the first ten instances in the table
for instance in cur_1.execute('SELECT * FROM Listings LIMIT 10;'):
    print(instance)
# Out:
# (0, 2384, '(Hyde Park - Walk to UChicago/Theological Seminary)', 2613, 'Rebecca', None, 'hyde park', 41.7888649, -87.58670891, 'Private room', 50, 2, 137, '11/12/18', 2.92, 1, 163)
# (1, 6715, '(Lincoln Park Oasis - Unit 2 ONLY)', 15365, 'Reem', None, 'OHARE', 41.92926222, -87.66009125, 'Entire home/apt', 255, 4, 93, '8/12/18', 0.81, 2, 303)
# (2, 7126, '(Tiny Studio Apartment 94 Walk Score)', 17928, 'Sarah', None, 'West Town', 41.90289494, -87.68182159999999, 'Entire home/apt', 80, 2, 321, '10/29/18', 2.81, 1, 362)
# (3, 9811, "(Barbara's Hideaway - Old Town)", 33004, '  At Home Inn', None, 'Lincoln Park', 41.91768924, -87.63787944, 'Entire home/apt', 150, 3, 33, '10/14/18', 0.59, 9, 350)
# (4, 10610, '(3 Comforts of Cooperative Living)', 2140, 'Lois And Ed', None, 'hyde park', 41.79708495, -87.59194894, 'Private room', 35, 2, 31, '7/29/18', 0.63, 5, 179)
# (5, 10945, '(The Biddle House (#1))', 33004, '  At Home Inn', None, 'Lincoln Park', 41.91182685, -87.63999816, 'Entire home/apt', 215, 3, 9, '11/5/18', 0.16, 9, 357)
# (6, 12068, '(Chicago GOLD COAST 1 Bedroom Condo)', 40731, 'Dominic', None, 'Near North Side', 41.904520899999994, -87.63320022, 'Entire home/apt', 99, 165, 8, '10/24/17', 0.18, 2, 303)
# (7, 12140, '(Lincoln Park Guest House)', 46734, 'Sharon And Robert', None, 'Lincoln Park', 41.92335308, -87.64950966, 'Private room', 289, 2, 4, '10/17/18', 0.1, 1, 169)
# (8, 22362, '(*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **)', 85811, 'Craig', None, 'West Town', 41.89616805, -87.66041074, 'Entire home/apt', 99, 60, 9, '10/12/14', 0.15, 1, 280)
# (9, 22651, '(beautifully furnished 3 bed/1bath 1)', 87231, 'Jeff And JoAnne', None, 'Lake view', 41.94910517, -87.65790583, 'Entire home/apt', 185, 1, 174, '10/21/18', 1.69, 17, 71)

# %%
# Save and close database connection
con_1.commit()
con_1.close()

# %% [markdown]
# #### TASK 1.2: Interacting with data through a more user-friendly interface
# As you might have noticed, interacting with data using the above method is difficult. Not only will you need to formulate your query as a string input to the ```execute``` method in ```sqlite3```, you will also need to print out the returned instances using a ```for``` loop. Here we introduce you to our user-friendly interface for interacting with data stored in ```sqlite3``` databases. While the technical details of our interface are beyond the scope of this tutorial, we hope that our interface will help you not only navigate this tutorial more easily but also understand how ```sqlite3``` might be enhanced.

# %%
# Create database connection
# %reload_ext sql
# %reload_ext lib.sqlite.sqlite_evaluate_magic
con_2 = 'sqlite:///' + os.path.expanduser('airbnb2.db')
# %sql $con_2
# Out:
# 'Connected: @airbnb2.db'

# %%
# Create database table from pandas DataFrame object created earlier
df.to_sql('Listings', con_2)

# %%
# %%sql
# -- View the first ten instances in the table
# SELECT *
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(0, 2384, '(Hyde Park - Walk to UChicago/Theological Seminary)', 2613, 'Rebecca', None, 'hyde park', 41.7888649, -87.58670891, 'Private room', 50, 2, 137, '11/12/18', 2.92, 1, 163),
#  (1, 6715, '(Lincoln Park Oasis - Unit 2 ONLY)', 15365, 'Reem', None, 'OHARE', 41.92926222, -87.66009125, 'Entire home/apt', 255, 4, 93, '8/12/18', 0.81, 2, 303),
#  (2, 7126, '(Tiny Studio Apartment 94 Walk Score)', 17928, 'Sarah', None, 'West Town', 41.90289494, -87.68182159999999, 'Entire home/apt', 80, 2, 321, '10/29/18', 2.81, 1, 362),
#  (3, 9811, "(Barbara's Hideaway - Old Town)", 33004, '  At Home Inn', None, 'Lincoln Park', 41.91768924, -87.63787944, 'Entire home/apt', 150, 3, 33, '10/14/18', 0.59, 9, 350),
#  (4, 10610, '(3 Comforts of Cooperative Living)', 2140, 'Lois And Ed', None, 'hyde park', 41.79708495, -87.59194894, 'Private room', 35, 2, 31, '7/29/18', 0.63, 5, 179),
#  (5, 10945, '(The Biddle House (#1))', 33004, '  At Home Inn', None, 'Lincoln Park', 41.91182685, -87.63999816, 'Entire home/apt', 215, 3, 9, '11/5/18', 0.16, 9, 357),
#  (6, 12068, '(Chicago GOLD COAST 1 Bedroom Condo)', 40731, 'Dominic', None, 'Near North Side', 41.904520899999994, -87.63320022, 'Entire home/apt', 99, 165, 8, '10/24/17', 0.18, 2, 303),
#  (7, 12140, '(Lincoln Park Guest House)', 46734, 'Sharon And Robert', None, 'Lincoln Park', 41.92335308, -87.64950966, 'Private room', 289, 2, 4, '10/17/18', 0.1, 1, 169),
#  (8, 22362, '(*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **)', 85811, 'Craig', None, 'West Town', 41.89616805, -87.66041074, 'Entire home/apt', 99, 60, 9, '10/12/14', 0.15, 1, 280),
#  (9, 22651, '(beautifully furnished 3 bed/1bath 1)', 87231, 'Jeff And JoAnne', None, 'Lake view', 41.94910517, -87.65790583, 'Entire home/apt', 185, 1, 174, '10/21/18', 1.69, 17, 71)]

# %% [markdown]
# ### TASK 2: INTEGRITY CONSTRAINT VIOLATIONS AND REPAIRS
# ##### Description: Congratulations, you are now able to interact with your data using our user-friendly interface! Now let's start writing some queries to identify some of the data quality issues in this dataset. Usually integrity constraints are used to prevent low-quality data from being entered into your database, but here we'd like you to use integrity constraints to identify low-quality data that are already in the dataset (i.e. those that violate the integrity constraints). The advantage of using SQL to do this is that it allows you to write semantically unambiguous and logically sound queries to fast identify data you want (or, in our case here, those you don't want). Once those data are identified, you can then decide how to fix the data quality issues found in the data.

# %% [markdown]
# #### TASK 2.1: Checking the ```id``` column

# %%
# %%sql
# -- Check if there's any missing data in id column
# SELECT *
# FROM Listings
# WHERE id IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- Check if there's any id values that are not unique (i.e. have more than one occurrences)
# SELECT id, COUNT(id) AS id_count
# FROM Listings
# GROUP BY id
# HAVING COUNT(id) > 1;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %% [markdown]
# #### TASK 2.2: Checking and fixing the ```name``` column

# %%
# %%sql
# -- Check if there's any missing data in name column
# SELECT *
# FROM Listings
# WHERE name IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- Replace left parenthesis using REPLACE function
# SELECT name, REPLACE(name, '(', '') AS updated_name
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [('(Hyde Park - Walk to UChicago/Theological Seminary)', 'Hyde Park - Walk to UChicago/Theological Seminary)'),
#  ('(Lincoln Park Oasis - Unit 2 ONLY)', 'Lincoln Park Oasis - Unit 2 ONLY)'),
#  ('(Tiny Studio Apartment 94 Walk Score)', 'Tiny Studio Apartment 94 Walk Score)'),
#  ("(Barbara's Hideaway - Old Town)", "Barbara's Hideaway - Old Town)"),
#  ('(3 Comforts of Cooperative Living)', '3 Comforts of Cooperative Living)'),
#  ('(The Biddle House (#1))', 'The Biddle House #1))'),
#  ('(Chicago GOLD COAST 1 Bedroom Condo)', 'Chicago GOLD COAST 1 Bedroom Condo)'),
#  ('(Lincoln Park Guest House)', 'Lincoln Park Guest House)'),
#  ('(*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **)', '*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **)'),
#  ('(beautifully furnished 3 bed/1bath 1)', 'beautifully furnished 3 bed/1bath 1)')]

# %%
# %%sql
# -- Update original table with changes
# UPDATE Listings
# SET name = REPLACE(name, '(', '');
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# 7594 rows affected.
# []

# %%
# %%sql
# -- Replace right parenthesis using REPLACE function
# SELECT name, REPLACE(name, ')', '') AS updated_name
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [('Hyde Park - Walk to UChicago/Theological Seminary)', 'Hyde Park - Walk to UChicago/Theological Seminary'),
#  ('Lincoln Park Oasis - Unit 2 ONLY)', 'Lincoln Park Oasis - Unit 2 ONLY'),
#  ('Tiny Studio Apartment 94 Walk Score)', 'Tiny Studio Apartment 94 Walk Score'),
#  ("Barbara's Hideaway - Old Town)", "Barbara's Hideaway - Old Town"),
#  ('3 Comforts of Cooperative Living)', '3 Comforts of Cooperative Living'),
#  ('The Biddle House #1))', 'The Biddle House #1'),
#  ('Chicago GOLD COAST 1 Bedroom Condo)', 'Chicago GOLD COAST 1 Bedroom Condo'),
#  ('Lincoln Park Guest House)', 'Lincoln Park Guest House'),
#  ('*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **)', '*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **'),
#  ('beautifully furnished 3 bed/1bath 1)', 'beautifully furnished 3 bed/1bath 1')]

# %%
# %%sql
# -- Update original table with changes
# UPDATE Listings
# SET name = REPLACE(name, ')', '');
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# 7594 rows affected.
# []

# %%
# %%sql
# -- Replace asterisk using REPLACE function
# SELECT name, REPLACE(name, '*', '') AS updated_name
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [('Hyde Park - Walk to UChicago/Theological Seminary', 'Hyde Park - Walk to UChicago/Theological Seminary'),
#  ('Lincoln Park Oasis - Unit 2 ONLY', 'Lincoln Park Oasis - Unit 2 ONLY'),
#  ('Tiny Studio Apartment 94 Walk Score', 'Tiny Studio Apartment 94 Walk Score'),
#  ("Barbara's Hideaway - Old Town", "Barbara's Hideaway - Old Town"),
#  ('3 Comforts of Cooperative Living', '3 Comforts of Cooperative Living'),
#  ('The Biddle House #1', 'The Biddle House #1'),
#  ('Chicago GOLD COAST 1 Bedroom Condo', 'Chicago GOLD COAST 1 Bedroom Condo'),
#  ('Lincoln Park Guest House', 'Lincoln Park Guest House'),
#  ('*** Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ **', ' Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ '),
#  ('beautifully furnished 3 bed/1bath 1', 'beautifully furnished 3 bed/1bath 1')]

# %%
# %%sql
# -- Update original table with changes
# UPDATE Listings
# SET name = REPLACE(name, '*', '');
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# 7594 rows affected.
# []

# %%
# %%sql
# -- Trim leading and trailing whitespace using TRIM function
# SELECT name, TRIM(name, ' ') AS updated_name
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [('Hyde Park - Walk to UChicago/Theological Seminary', 'Hyde Park - Walk to UChicago/Theological Seminary'),
#  ('Lincoln Park Oasis - Unit 2 ONLY', 'Lincoln Park Oasis - Unit 2 ONLY'),
#  ('Tiny Studio Apartment 94 Walk Score', 'Tiny Studio Apartment 94 Walk Score'),
#  ("Barbara's Hideaway - Old Town", "Barbara's Hideaway - Old Town"),
#  ('3 Comforts of Cooperative Living', '3 Comforts of Cooperative Living'),
#  ('The Biddle House #1', 'The Biddle House #1'),
#  ('Chicago GOLD COAST 1 Bedroom Condo', 'Chicago GOLD COAST 1 Bedroom Condo'),
#  ('Lincoln Park Guest House', 'Lincoln Park Guest House'),
#  (' Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ ', 'Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ'),
#  ('beautifully furnished 3 bed/1bath 1', 'beautifully furnished 3 bed/1bath 1')]

# %%
# %%sql
# -- Update original table with changes
# UPDATE Listings
# SET name = TRIM(name, ' ');
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# 7594 rows affected.
# []

# %% [markdown]
# #### TASK 2.3: Checking the ```host_id``` column

# %%
# %%sql
# -- Check if there's any missing data in host_id column
# SELECT *
# FROM Listings
# WHERE host_id IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %% [markdown]
# #### TASK 2.4: Checking and fixing the ```host_name``` column

# %%
# %%sql
# -- Check if there's any missing data in host_name column
# SELECT *
# FROM Listings
# WHERE host_name IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(1520, 12169862, 'Newly Furnished/Family Friendly Great Neighborhood', 44002119, None, None, 'Lake view', 41.9384146, -87.67030584, 'Entire home/apt', 235, 2, 88, '11/14/18', 2.86, 1, 347),
#  (3124, 19111753, 'Nice one bedroom/bath in the South Shore area.', 26381069, None, None, 'South Shore', 41.76593439, -87.59141682, 'Private room', 52, 1, 11, '10/7/18', 0.63, 1, 365),
#  (5149, 24562425, "Dorothy's Place Easy Access To Downtown Chicago", 185579695, None, None, 'Austin', 41.87560963, -87.75510044, 'Entire home/apt', 125, 1, 26, '11/4/18', 4.73, 1, 228)]

# %%
# %%sql
# -- Check if there's other instances that share the same host_id values
# -- so that we can recover missing values in host_name column
# SELECT host_id, host_name
# FROM Listings
# WHERE host_id = 44002119 OR host_id = 26381069 OR host_id = 185579695;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(44002119, None), (26381069, None), (185579695, None)]

# %%
# %%sql
# -- Change "And" to "&" using REPLACE function for ease of reading
# SELECT host_name, REPLACE(host_name, ' And ', ' & ') AS updated_host_name
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [('Rebecca', 'Rebecca'),
#  ('Reem', 'Reem'),
#  ('Sarah', 'Sarah'),
#  ('  At Home Inn', '  At Home Inn'),
#  ('Lois And Ed', 'Lois & Ed'),
#  ('  At Home Inn', '  At Home Inn'),
#  ('Dominic', 'Dominic'),
#  ('Sharon And Robert', 'Sharon & Robert'),
#  ('Craig', 'Craig'),
#  ('Jeff And JoAnne', 'Jeff & JoAnne')]

# %%
# %%sql
# -- Update original table with changes
# UPDATE Listings
# SET host_name = REPLACE(host_name, ' And ', ' & ');
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# 7594 rows affected.
# []

# %%
# %%sql
# -- Trim leading and trailing whitespace using TRIM function
# SELECT host_name, TRIM(host_name, ' ') AS updated_host_name
# FROM Listings
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [('Rebecca', 'Rebecca'),
#  ('Reem', 'Reem'),
#  ('Sarah', 'Sarah'),
#  ('  At Home Inn', 'At Home Inn'),
#  ('Lois & Ed', 'Lois & Ed'),
#  ('  At Home Inn', 'At Home Inn'),
#  ('Dominic', 'Dominic'),
#  ('Sharon & Robert', 'Sharon & Robert'),
#  ('Craig', 'Craig'),
#  ('Jeff & JoAnne', 'Jeff & JoAnne')]

# %%
# %%sql
# -- Update original table with changes
# UPDATE Listings
# SET host_name = TRIM(host_name, ' ');
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# 7594 rows affected.
# []

# %% [markdown]
# #### TASK 2.5: Checking the ```price``` column

# %%
# %%sql
# -- Check if there's any missing data in price column
# SELECT *
# FROM Listings
# WHERE price IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- Check potential irregularities in price column
# SELECT *
# FROM Listings
# WHERE price > 300 OR price < 20;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(31, 145690, '4BR/2BR Walk to North Ave Beach & Zoo~Close to El', 683529, 'Joe', None, 'Lincoln Park', 41.91350805, -87.63929446, 'Entire home/apt', 475, 2, 35, '10/9/18', 0.83, 20, 354),
#  (56, 267299, 'Family Style Home-walk to Aragon/Riviera', 272671, 'Two For The Road', None, 'Uptown', 41.96924262, -87.65807228, 'Entire home/apt', 750, 1, 16, '4/25/14', 0.19, 4, 357),
#  (67, 325842, 'Lincoln Park Sunny Modern Home', 1666599, 'Caroline', None, 'Lincoln Park', 41.92026289, -87.65891590000001, 'Entire home/apt', 379, 6, 25, '9/22/18', 0.31, 1, 358),
#  (69, 349265, 'Historic Chicago Home - Hyde Park', 1517871, 'Jon', None, 'hyde park', 41.8008596, -87.58948398, 'Entire home/apt', 375, 7, 8, '9/17/18', 0.1, 2, 342),
#  (93, 573540, 'Drop-dead fab on the Lake  2bd/2bth', 919011, 'Jacqueline', None, 'Lake view', 41.94284298, -87.63918952, 'Entire home/apt', 490, 1, 35, '9/21/15', 0.46, 2, 365),
#  (112, 699284, 'Your Sweet Chicago Home', 3586103, 'Judy', None, 'Lincoln Park', 41.92929141, -87.64894838, 'Entire home/apt', 800, 3, 42, '7/23/18', 0.57, 1, 358),
#  (290, 2483579, 'Luxe Condo in Wicker Park/Bucktown', 8896092, 'Julia', None, 'West Town', 41.89930104, -87.66582058, 'Entire home/apt', 375, 2, 156, '11/4/18', 2.89, 1, 79),
#  (294, 2512850, 'THE GREEN ROOM IN ANDERSONVILLE', 9313520, 'Taylor', None, 'Uptown', 41.97487205, -87.67027101, 'Private room', 4137, 2, 218, '10/29/18', 3.99, 1, 336),
#  (318, 2817608, 'Luxury Three Bedroom, Two Bathroom Apartment', 791089, 'Conrad', None, 'Lake view', 41.94278185, -87.67221493, 'Entire home/apt', 380, 3, 12, '8/13/18', 0.23, 4, 365),
#  (333, 3010785, 'Modern single family home', 15343214, 'Mark', None, 'Logan Square', 41.9145966, -87.69045025, 'Entire home/apt', 475, 1, 91, '11/4/18', 1.74, 1, 178),
#  (349, 3172794, 'LOFT606:  Gigantic Sunlit Loft!', 16090300, 'John', None, 'Logan Square', 41.91704143, -87.69375214, 'Entire home/apt', 1200, 2, 38, '10/18/18', 0.73, 1, 354),
#  (355, 3292054, 'The Roscoe House near Wrigley Field', 5960265, 'Garrett & Courtney', None, 'Lake view', 41.94313274, -87.65612607, 'Entire home/apt', 450, 2, 127, '10/14/18', 2.41, 4, 318),
#  (363, 3317508, 'Light and Airy Chicago Apartment', 15438417, 'Kiril', None, 'Uptown', 41.96932065, -87.65132303, 'Entire home/apt', 370, 2, 22, '10/7/18', 0.57, 1, 45),
#  (368, 3385966, 'Welcome to your 2BD Penthouse', 9995028, 'Chad', None, 'Lake view', 41.9375523, -87.66932251, 'Entire home/apt', 2000, 100, 120, '4/1/18', 2.78, 1, 365),
#  (378, 3488317, 'Brewers & Reds  vs Cubs Wrigleyville - 3 bdrms', 3621097, 'Marcus', None, 'Lake view', 41.94328457, -87.64870079, 'Entire home/apt', 375, 1, 6, '9/16/18', 0.36, 2, 0),
#  (381, 3521727, 'Penthouse condo w/ private roof deck! 2BR / 2 BA', 17733782, 'Brittany', None, 'Lake view', 41.940092299999996, -87.65696616, 'Entire home/apt', 330, 4, 9, '7/22/18', 0.17, 1, 0),
#  (430, 3946689, 'Beautifull and cozy studio in Lakeview', 10926285, 'Paola', None, 'Lake view', 41.95293143, -87.66995341, 'Entire home/apt', 1000, 2, 19, '8/19/18', 0.46, 1, 63),
#  (445, 4032955, 'Private Room', 20908628, 'Steve', None, 'Logan Square', 41.91841939, -87.67366608, 'Private room', 500, 1, 1, '6/1/15', 0.02, 1, 363),
#  (467, 4192849, 'The House', 11231030, 'Erik', None, 'West Lawn', 41.78395637, -87.72969372, 'Shared room', 12, 1, 13, '5/17/17', 0.3, 3, 0),
#  (489, 4365466, '01a. Queen bed in Coed Space - 3 mi from NWU', 2907254, 'Joe', None, 'West Ridge', 42.01538263, -87.68876103, 'Shared room', 17, 1, 87, '10/14/18', 1.76, 16, 0),
#  (521, 4668682, 'Adjoining Loft Apartments', 10363033, 'Jessica', None, 'Lincoln Park', 41.91688142, -87.63564168, 'Entire home/apt', 743, 1, 83, '10/21/18', 1.79, 4, 312),
#  (2111, 14899316, "A Stone's Throw from Wrigley Field ?__ -  4BR", 8549643, 'George & Sean', None, 'Lake view', 41.95287798, -87.65509452, 'Entire home/apt', 549, 1, 52, '11/11/18', 2.05, 25, 158),
#  (2133, 15006644, 'PRESIDENTIAL SUITE - 1 Bedroom - LUXURY', 64065593, 'ResortShare5', None, 'L??p', 41.887690899999996, -87.62594784, 'Entire home/apt', 312, 2, 0, None, None, 6, 0),
#  (2134, 15006829, '2 Bedroom Presidential ??? Grand Chicago Resort', 64065593, 'ResortShare5', None, 'L??p', 41.88798494, -87.6248487, 'Entire home/apt', 390, 2, 0, None, None, 6, 0),
#  (2160, 15082151, 'Penthouse Two Blocks from Grant Park', 22377883, 'Pete', None, 'L??p', 41.88377418, -87.62610141, 'Entire home/apt', 500, 2, 0, None, None, 1, 0),
#  (2189, 15216226, 'Luxury Single-Family Home Near Wrigley Field', 96680775, 'Todd', None, 'North Center', 41.94464916, -87.68397237, 'Entire home/apt', 1800, 2, 1, '7/14/17', 0.06, 1, 365),
#  (2192, 15217088, 'Modern Condo with roofdeck where East meets West!', 10613587, 'Saurin', None, 'West Town', 41.89462894, -87.6594265, 'Entire home/apt', 600, 2, 64, '10/28/18', 2.6, 4, 162),
#  (2193, 15219844, 'Beautiful 2bdrm condo in Lakeview', 46663875, 'Alex', None, 'Lake view', 41.93880295, -87.65367123, 'Entire home/apt', 1200, 1, 7, '7/1/18', 0.28, 1, 89),
#  (2195, 15230450, 'Wrigleyville townhome two blocks from ballpark', 96809854, 'Ute', None, 'Lake view', 41.95156029, -87.657351, 'Entire home/apt', 350, 2, 28, '11/12/18', 1.13, 1, 365),
#  (2201, 15256305, 'Beautiful Large Condo in Lakeview Near Wrigley', 246696, 'Simon', None, 'Lake view', 41.9360309, -87.64278644, 'Entire home/apt', 550, 2, 1, '6/4/17', 0.06, 1, 0),
#  (2213, 15287352, 'Wrigleyville Mansion - Sleeps 16+', 45401863, 'Joe', None, 'Lake view', 41.9511223, -87.67020006, 'Entire home/apt', 3000, 1, 15, '11/5/18', 0.86, 2, 86),
#  (2218, 15296005, 'High End Wrigleyville Condo - 1/4 block to Stadium', 97384539, 'Kyle', None, 'Lake view', 41.95025416, -87.65782455, 'Entire home/apt', 600, 2, 1, '10/31/16', 0.04, 1, 0),
#  (2234, 15338402, 'Antique Filled Penthouse w/ Views', 5860808, 'Amanda', None, 'Lincoln Park', 41.93128574, -87.65677839, 'Entire home/apt', 1500, 1, 0, None, None, 1, 365),
#  (2243, 15374367, 'Hotel Gravy', 97691217, 'Dan', None, 'Lincoln Park', 41.93065095, -87.64200763, 'Entire home/apt', 400, 2, 21, '10/21/18', 0.82, 1, 178),
#  (2254, 15406653, 'Groups - Christmas Shopping Trip  Retreat!', 3314137, 'Jessie', None, 'Lincoln Park', 41.9159174, -87.65655841, 'Entire home/apt', 400, 3, 1, '7/8/17', 0.06, 1, 290),
#  (2712, 17528120, "Adeline's Sea Moose, 68 ft luxury yacht, sleeps 6", 118859633, "Adeline'S Sea Moose", None, 'Near South Side', 41.85960916, -87.61321475, 'Entire home/apt', 1200, 1, 1, '4/15/18', 0.14, 1, 227),
#  (2722, 17601367, 'Gold Coast/Michigan Ave/Downtown 2 Bedroom Duplex', 107355427, 'Colleen', None, 'Near North Side', 41.89940782, -87.62654901, 'Entire home/apt', 650, 2, 4, '6/29/18', 0.26, 5, 0),
#  (2724, 17620294, 'Condo with Patio and Outdoor Kitchen near Wrigley Field', 63775419, 'Tiffany & Jeff', None, 'Lake view', 41.95040617, -87.65118594, 'Entire home/apt', 850, 3, 25, '10/20/18', 1.63, 1, 258),
#  (2736, 17711999, 'Luxury Loft Apt. at FieldHouse Jones', 92467320, 'FieldHouse', None, 'Near North Side', 41.89762829, -87.63499628, 'Entire home/apt', 500, 1, 42, '11/4/18', 2.08, 8, 257),
#  (2737, 17713737, 'Brand New Designer 3bd -- Steps from Wrigley Field', 99537072, 'Patrick', None, 'Lake view', 41.94695826, -87.65329452, 'Entire home/apt', 700, 1, 48, '10/22/18', 4.51, 2, 88),
#  (2755, 17807776, '10% OFF Family retreat at McCormick Place Chicago', 121705751, 'Vaida', None, 'Bridgeport', 41.84212154, -87.66338996, 'Entire home/apt', 500, 2, 1, '5/11/18', 0.16, 1, 323),
#  (2766, 17859080, 'Safest area ComfySmarthome by CTA close to Wrigley', 34130188, 'Damoon', None, 'North Center', 41.95452637, -87.67557155, 'Entire home/apt', 618, 1, 27, '10/21/18', 1.57, 3, 345),
#  (2777, 17903682, 'Airy modern home in the heart of Lincoln Square', 6467011, 'Steven', None, 'Lincoln Square', 41.96502384, -87.68094004, 'Entire home/apt', 400, 2, 1, '5/31/17', 0.06, 1, 0),
#  (2799, 18007859, 'Gorgeous Modern Home with Enviable Outdoor Living', 1812643, 'Dior', None, 'West Town', 41.89273426, -87.67360591, 'Entire home/apt', 649, 1, 29, '10/21/18', 1.61, 1, 359),
#  (2801, 18018011, 'Single family home on quiet street in Logan Square', 8185293, 'Marshall', None, 'Logan Square', 41.9252798, -87.71130923, 'Entire home/apt', 350, 3, 2, '7/31/17', 0.11, 1, 74),
#  (2814, 18090895, 'Penthouse Loft Apt. at FieldHouse Jones', 92467320, 'FieldHouse', None, 'Near North Side', 41.89852044, -87.63555408, 'Entire home/apt', 500, 1, 27, '11/6/18', 1.48, 8, 224),
#  (2819, 18096865, 'Sky-High Home near Navy Pier and the Magnificent Mile', 24388042, 'DeLuxe', None, 'Near North Side', 41.89375583, -87.61686413, 'Entire home/apt', 400, 30, 18, '7/28/18', 0.99, 10, 353),
#  (2835, 18175476, 'Hotel perks without the price', 57387860, 'Freehand', None, 'Near North Side', 41.89354279, -87.62706307, 'Private room', 600, 7, 6, '9/18/18', 0.36, 33, 322),
#  (2840, 18194698, 'Stunning and Spacious Lincoln Park Home Allows Your Group to Live Like Locals', 110985389, 'Josh', None, 'Lincoln Park', 41.91614768, -87.65059806, 'Entire home/apt', 800, 3, 29, '10/28/18', 1.52, 1, 342),
#  (2841, 18208652, 'Corner Studio Loft at FieldHouse Jones', 92467320, 'FieldHouse', None, 'Near North Side', 41.
#  (3122, 19101426, '3 BR East Lakeview Coach House with Large Patio', 118232209, 'Eric & Beth', None, 'Lake view', 41.93408886, -87.63960377, 'Entire home/apt', 350, 1, 52, '10/14/18', 3.01, 2, 342),
#  (3142, 19144659, 'The Jetson House - with Smart Home Technologies#', 73912900, 'Aaron', None, 'Woodlawn', 41.77406159, -87.59142936, 'Entire home/apt', 400, 2, 40, '10/22/18', 2.41, 1, 289),
#  (3164, 19208256, 'The Grand Kimball Lodge', 11266083, 'HyMay', None, 'Logan Square', 41.92203085, -87.71194625, 'Entire home/apt', 450, 3, 25, '10/29/18', 1.6, 1, 92),
#  (3189, 19316227, '#2Bed Penthouse/Free Parking/SunsetViews/McCormick', 72670952, 'Aqueelah', None, 'Near South Side', 41.8562975, -87.62437381, 'Entire home/apt', 329, 2, 37, '10/17/18', 2.45, 7, 158),
#  (3190, 19327931, '3br, 2 bath kid friendly apt w/ free parking', 44967753, 'Peter', None, 'Lincoln Square', 41.96885646, -87.68699425, 'Entire home/apt', 350, 3, 0, None, None, 1, 0),
#  (3195, 19348305, 'Gorgeous Boystown Penthouse', 5760690, 'Lindsay', None, 'Lake view', 41.93648606, -87.64671042, 'Entire home/apt', 390, 2, 1, '8/6/18', 0.29, 1, 3),
#  (3200, 19399921, 'Lovely 3/2.5 duplex in Wicker Park area', 19061917, 'Anne', None, 'West Town', 41.90045907, -87.66332385, 'Entire home/apt', 399, 3, 11, '9/24/18', 0.68, 1, 306),
#  (3201, 19412268, 'Bright, Aloha Vibes in the Heart of Wicker Park', 4069585, 'Liz', None, 'West Town', 41.90749309, -87.67565625, 'Entire home/apt', 650, 1, 20, '10/16/18', 1.5, 13, 305),
#  (3253, 19574382, 'Historic Old Town, Fabulous 4 Bedroom Home', 33004, 'At Home   Inn', None, 'Lincoln Park', 41.91323809, -87.63969138, 'Entire home/apt', 400, 4, 16, '10/12/18', 1.05, 9, 243),
#  (3260, 19587548, 'Gold Coast/Michigan Ave/Downtown 1 Bedroom', 107355427, 'Colleen', None, 'Near North Side', 41.89972236, -87.62495899999999, 'Entire home/apt', 365, 2, 4, '8/5/18', 0.63, 5, 14),
#  (3277, 19643452, 'Large 1 bedroom with Private Bath', 4404730, 'Kyle', None, 'Lake view', 41.93917174, -87.64981938, 'Private room', 9999, 80, 2, '8/8/17', 0.13, 1, 363),
#  (3282, 19659523, 'Wicker Park 2 Bed/2.5 bath sleeps 6', 99894346, 'Andrew', None, 'West Town', 41.90774134, -87.66766872, 'Entire home/apt', 400, 2, 2, '8/6/17', 0.12, 1, 0),
#  (3303, 19736924, 'Lakeview Chicago condo - great location & parking', 73439247, 'Carol', None, 'Lake view', 41.94324292, -87.64354762, 'Entire home/apt', 385, 3, 4, '10/8/18', 0.29, 1, 279),
#  (3344, 19847846, 'Spacious 1bd: Streeterville, Rooftop Pool!', 12737000, 'Taylor', None, 'Near North Side', 41.89331371, -87.62029283, 'Entire home/apt', 600, 2, 0, None, None, 1, 0),
#  (6906, 28779817, 'BEAUTIFUL CENTRALLY LOCATED ROOM & FREE PARKING', 99375151, 'Marina', None, 'Near West Side', 41.8784797, -87.64591804, 'Private room', 19, 1, 8, '10/24/18', 5.11, 40, 63),
#  (6911, 28781858, '2 BEDS, CENTRAL DOWNTOWN LOCATION + FREE PARKING', 99375151, 'Marina', None, 'Near West Side', 41.878795399999994, -87.64824849, 'Private room', 19, 1, 10, '10/28/18', 6.0, 40, 70),
#  (6934, 28833654, 'Chicago Coach House', 216469913, 'Ethan', None, 'West Town', 41.89906971, -87.67070611, 'Entire home/apt', 5000, 3, 0, None, None, 1, 50),
#  (6944, 28861548, 'CORNER BUNK UNIT OVERLOOKING LAKE MICHIGAN 2br/2ba', 63313003, 'K', None, 'L??p', 41.88645302, -87.61640159, 'Entire home/apt', 331, 14, 0, None, None, 17, 274),
#  (6972, 28931749, '?_??ُAwesome Location!! 2 Adjoining flats in Wrigley!', 72176805, 'Ryan & Bethany', None, 'Lake view', 41.94612335, -87.65421899, 'Entire home/apt', 479, 1, 1, '11/11/18', 1.0, 3, 97),
#  (7007, 28981805, 'COZY ROOM, FREE PARKING, 7MN TO WILLIS TOWER & UIC', 99375151, 'Marina', None, 'Near West Side', 41.87999929, -87.64960072, 'Private room', 19, 1, 10, '10/27/18', 7.69, 40, 70),
#  (7009, 28982853, 'Penthouse 2 bedroom/2.5 bathroom', 218452414, 'Timothy', None, 'Uptown', 41.9690425, -87.65632488, 'Entire home/apt', 550, 4, 0, None, None, 3, 83),
#  (7011, 28984416, 'Newly renovated oversized 5 bed/2 bath 3000 sq ft', 209960366, 'Terese', None, 'Irving Park', 41.95665043, -87.69926121, 'Entire home/apt', 400, 2, 0, None, None, 2, 364),
#  (7014, 28985259, 'Electric West Town Home next to Blue Line', 57401418, 'Elizabeth', None, 'West Town', 41.89443924, -87.6581452, 'Entire home/apt', 550, 1, 4, '10/21/18', 3.0, 1, 178),
#  (7024, 29015114, 'New! Stylish 3br Loft in Wicker Park', 143825988, 'Reserve', None, 'West Town', 41.90522753, -87.66732345, 'Entire home/apt', 1499, 2, 3, '10/18/18', 2.57, 33, 103),
#  (7028, 29020361, 'Private Room in Washington Park', 11708125, 'Tifa', None, 'Washington Park', 41.78997252, -87.62527283, 'Private room', 15, 2, 0, None, None, 3, 70),
#  (7053, 29061285, 'The Sunflower Rm: Simple.Bright.Comfy.Convenient.', 153829791, 'Venisha', None, 'Washington Heights', 41.73079171, -87.65913299, 'Private room', 18, 1, 6, '11/5/18', 5.29, 2, 172),
#  (7060, 29076635, 'PERFECT DOWNTOWN ROOM 2 BEDS + FREE PARKING & WIFI', 99375151, 'Marina', None, 'Near West Side', 41.87996323, -87.64259112, 'Private room', 19, 1, 4, '10/28/18', 4.0, 40, 75),
#  (7061, 29076863, 'BEAUTIFUL QUIET ROOM, FREE PARKING ONLY 5MN TO UIC', 99375151, 'Marina', None, 'Near West Side', 41.88031451, -87.64287517, 'Private room', 19, 1, 6, '10/31/18', 4.86, 40, 70),
#  (7067, 29093360, 'AirBnB meets Hotel - 1 bedroom', 57387860, 'Freehand', None, 'Near North Side', 41.89144825, -87.62681427, 'Private room', 600, 5, 0, None, None, 33, 365),
#  (7100, 29150912, '4 Bedroom Duplex West Town', 87585422, 'Dan', None, 'West Town', 41.90933616, -87.66495451, 'Entire home/apt', 395, 3, 0, None, None, 1, 45),
#  (7105, 29155607, 'Beautiful Art Deco Apt With Stunning Views', 1413606, 'Michael', None, 'Lake view', 41.94148386, -87.64126954, 'Entire home/apt', 350, 3, 0, None, None, 2, 347),
#  (7137, 29215772, 'New! Reserve Collection Penthouse in the Loop', 143825988, 'Reserve', None, 'L??p', 41.88363676, -87.62812041, 'Entire home/apt', 799, 2, 4, '10/28/18', 3.43, 33, 99),
#  (7140, 29216874, 'New! Luxury 3br in Chicago Loop', 143825988, 'Reserve', None, 'L??p', 41.8841064, -87.62905437, 'Entire home/apt', 799, 2, 3, '10/29/18', 2.57, 33, 78),
#  (7153, 29238367, '3min Walk to Milllennium Park, Near Loop & Skydeck', 220044968, 'Karine', None, 'L??p', 41.88769384, -87.6177765, 'Entire home/apt', 380, 2, 1, '10/22/18', 1.0, 1, 34),
#  (7161, 29261309, 'Chicago Multi-unit close to united center', 57544511, 'Bowen', None, 'Near West Side', 41.88190201, -87.68444316, 'Entire home/apt', 1500, 7, 0, None, None, 2, 18),
#  (7195, 29335246, 'Clark and Chicago 1 bedroom 1 bath all amenities', 218452414, 'Timothy', None, 'Near North Side', 41.89763619, -87.63258476, 'Entire home/apt', 350, 5, 0, None, None, 3, 83),
#  (7196, 29335832, 'Penthouse 1 Bedroom!', 218452414, 'Timothy', None, 'Uptown', 41.96827374, -87.65665113, 'Entire home/apt', 550, 3, 0, None, None, 3, 83),
#  (7200, 29339327, 'Open Concept Home ???Lincoln Park w/ Patio & Parking', 96813170, 'Cassidy', None, 'Lincoln Park', 41.92572108, -87.67017298, 'Entire home/apt', 399, 1, 2, '11/11/18', 2.0, 1, 355),
#  (7206, 29363835, 'Beautiful Penthouse in Wonderful Wicker Park', 216589393, 'Tasneem', None, 'West Town', 41.90467398, -87.67522336, 'Entire home/apt', 500, 1, 0, None, None, 4, 361),
#  (7208, 29369659, 'Film & Events in Private Home, Cannabis Friendly', 73119847, 'Holly', None, 'Washington Park', 41.79647703, -87.62218744, 'Private room', 1500, 1, 0, None, None, 2, 89),
#  (7228, 29411064, 'Ultimate Stay: 5,000 sqft Brand New Mega Mansion!', 221549517, 'Laurie', None, 'Lake view', 41.93996405, -87.66151088, 'Entire home/apt', 1500, 2, 0, None, None, 1, 287),
#  (7231, 29414127, 'Chicago apartment for the great location by United', 57544511, 'Bowen', None, 'Near West Side', 41.87719044, -87.68133671, 'Entire home/apt', 1500, 7, 0, None, None, 2, 170),
#  (7232, 29416910, 'NEW LISTING! Dog-friendly condo w/balcony, city views & shared pool/sauna/gym', 161474228, 'Vacasa Illinois', None, 'Near North Side', 41.89294805, -87.62775232, 'Entire home/apt', 353, 1, 0, None, None, 22, 341),
#  (7236, 29421194, 'New! Stylish 2br By Reserve Rentals', 143825988, 'Reserve', None, 'Near North Side', 41.897560600000006, -87.6280508, 'Entire home/apt', 1999, 2, 0, None, None, 33, 339),
#  (7239, 29423590, 'New! Upscale 2br in Gold Coast', 143825988, 'Reserve', None, 'Near North Side', 41.89802289, -87.62899505, 'Entire home/apt', 1999, 2, 0, None, None, 33, 339),
#  (7240, 29424181, 'New! Chic 1br in Gold Coast By Reserve Rentals', 143825988, 'Reserve', None, 'Near North Side', 41.89953793, -87.6279323, 'Entire home/apt', 1999, 2, 0, None, None, 33, 70),
#  (7251, 29435821, 'VERY BEAUTIFUL LOFT ROOM IN DOWNTOWN LOOP', 55976787, 'Natalia', None, 'Near West Side', 41.87887084, -87.63867797, 'Private room', 10, 1, 3, '10/26/18', 3.0, 34, 29),
#  (7253, 29436384, 'COMFORTABLE ROOM IN GREEKTOWN WITH FREE PARKING', 55976787, 'Natalia', None, 'Near West Side', 41.88008978, -87.63956125, 'Private room', 10, 1, 4, '10/31/18', 4.0, 34, 46),
#  (7258, 29437529, 'New! Airy 1BR with High Ceilings in South Loop', 143825988, 'Reserve', None, 'L??p', 41.86902631, -87.62636508, 'Entire home/apt', 1499, 2, 1, '10/25/18', 1.0, 33, 339),
#  (7265, 29458219, 'Shared bed room in a Manshion- Bed G', 163484540, 'Francineuma', None, 'Calumet Heights', 41.729455200000004, -87.5783169, 'Shared room', 13, 1, 2, '11/3/18', 2.0, 11, 362),
#  (7275, 29481145, 'BEAUTIFUL CENTRALLY LOCATED ROOM + FREE PARKING!', 55976787, 'Natalia', None, 'Near West Side', 41.87751048, -87.64851159999999, 'Private room', 19, 1, 3, '10/27/18', 3.0, 34, 64),
#  (7286, 29509898, 'Studio in the Heart of Chicago Downtown, Near Loop', 222190948, 'Regiana', None, 'L??p', 41.88759074, -87.61829701, 'Entire home/apt', 380, 2, 0, None, None, 1, 23),
#  (7293, 29517112, 'New Modern 3Bed/ 2/Bath in the heart of E Lakeview', 4203968, 'Lou', None, 'Lake view', 41.94186295, -87.64823195, 'Entire home/apt', 350, 2, 0, None, None, 1, 365),
#  (7299, 29519623, 'LOFT ROOM WITH 2 BEDS IN GREEKTOWN & FREE PARKING', 55976787, 'Natalia', None, 'Near West Side', 41.87874142, -87.63870156, 'Private room', 10, 1, 1, '10/26/18', 1.0, 34, 69),
#  (7306, 29536408, 'New! Upscale 3br Duplex in Old Town', 143825988, 'Reserve', None, 'Near North Side', 41.90965427, -87.63893709, 'Entire home/apt', 1999, 2, 2, '11/7/18', 2.0, 33, 329),
#  (7332, 29588271, 'Gorgeous Townhome in Old Town', 63656711, 'Lucas', None, 'Lincoln Park', 41.91585105, -87.634613, 'Entire home/apt', 390, 3, 0, None, None, 1, 83),
#  (7334, 29592300, 'NEW! Lincoln Park Luxury ??_?ُ near Night Life & Food', 35781467, 'Sonia & Syed', None, 'Lincoln Park', 41.91985976, -87.65265743, 'Entire home/apt', 500, 1, 2, '11/11/18', 2.0, 27, 356),
#  (7335, 29595175, 'Chicago Local Living, 4 Beds, Panoramic Roof Deck!', 145231565, 'Becky & Andrew', None, 'Near North Side', 41.91001152, -87.64167318, 'Entire home/apt', 499, 1, 0, None, None, 2, 89),
#  (7340, 29612381, 'Downtown Luxury Loft style 2B/2.5B apartment', 62050121, 'Michael', None, 'Near North Side', 41.89043769, -87.61796817, 'Entire home/apt', 335, 1, 0, None, None, 3, 349),
#  (7355, 29630119, 'BEAUTIFUL ROOM IN LOFT HOUSE IN DOWNTOWN CHICAGO', 55976787, 'Natalia', None, 'Near West Side', 41.87919266, -87.64121536, 'Private room', 10, 1, 1, '10/30/18', 1.0, 34, 53),
#  (7356, 29630512, 'STYLISH LOFT ROOM IN DOWNTOWN CHICAGO WITH PARKING', 55976787, 'Natalia', None, 'Near West Side', 41.8776401, -87.63951464, 'Private room', 10, 1, 0, None, None, 34, 48),
#  (7357, 29631546, "New! Traveler's Dream 2BR in Chicago Loop", 143825988, 'Reserve', None, 'L??p', 41.88313711, -87.62787274, 'Entire home/apt', 1999, 2, 0, None, None, 33, 76),
#  (7359, 29632125, 'New! Walkable 3BR in Chicago Loop', 143825988, 'Reserve', None, 'L??p', 41.88709123, -87.63417804, 'Entire home/apt', 1999, 2, 0, None, None, 33, 74),
#  (7371, 29659728, 'Sunny Corner Unit in the Heart of River North', 223241594, 'Walter', None, 'Near North Side', 41.89515654, -87.63363219, 'Entire home/apt', 500, 2, 0, None, None, 1, 127),
#  (7378, 29672965, 'Spacious Home Group/Family in Gold Coast-Old Town', 41862889, 'Inna', None, 'Near North Side', 41.90753936, -87.63765664, 'Entire home/apt', 399, 1, 0, None, None, 6, 337),
#  (7385, 29682272, '3-Story Spacious Home ??? Lincoln Park w/ Parking', 223387442, 'Matthew', None, 'Lincoln Park', 41.92344473, -87.65374939, 'Entire home/apt', 399, 2, 1, '11/12/18', 1.0, 1, 356),
#  (7386, 29683076, 'Entire Private Modern 3bed 3bath duplex, West Town', 40908312, 'Paul', None, 'West Town', 41.893337100000004, -87.66445808, 'Entire home/apt', 500, 1, 0, None, None, 2, 355),
#  (7396, 29706400, 'Sky Home near Navy Pier & the Magnificent Mile', 24388042, 'DeLuxe', None, 'Near North Side', 41.89193105, -87.61701995, 'Entire home/apt', 400, 3, 0, None, None, 10, 327),
#  (7397, 29707921, 'SLEEPS 21! Northside Home Near Wrigley, Lake', 17035591, 'Joshua', None, 'Uptown', 41.96265745, -87.66850967, 'Entire home/apt', 500, 1, 0, None, None, 3, 323),
#  (7405, 29732963, 'Luxurious one-bedroom condo', 189709549, 'Karen', None, 'Near North Side', 41.8956856, -87.62727109999999, 'Entire home/apt', 2500, 30, 0, None, None, 1, 363),
#  (7413, 29744244, '????ُ1Bed2Bath McCormick| Soldier Field |Grant Park????ُ', 72670952, 'Aqueelah', None, 'Near South Side', 41.85453952, -87.62659402, 'Entire home/apt', 329, 2, 0, None, None, 7, 137),
#  (7414, 29756628, 'Gold Coast/Michigan Ave/Downtown Penthouse Suite', 107355427, 'Colleen', None, 'Near North Side', 41.90077154, -87.62448081, 'Entire home/apt', 1000, 2, 0, None, None, 5, 72),
#  (7430, 29792567, 'NEW! Lincoln Park Luxury | Train, Food, Coffee??_?ُ', 35781467, 'Sonia & Syed', None, 'Lincoln Park', 41.91821768, -87.65393556, 'Entire home/apt', 500, 1, 1, '11/7/18', 1.0, 27, 75),
#  (7437, 29803091, 'DOWNTOWN ROOM WITH PRIVATE BATHROOM AND PARKING', 99375151, 'Marina', None, 'Near West Side', 41.87915122, -87.63845275, 'Private room', 19, 1, 0, None, None, 40, 362),
#  (7441, 29819119, 'Hotel meets AirBnB', 57387860, 'Freehand', None, 'Near North Side', 41.89299183, -87.62673704, 'Private room', 600, 3, 0, None, None, 33, 364),
#  (7442, 29819757, 'Hotel Meets AirBnB', 57387860, 'Freehand', None, 'Near North Side', 41.89345185, -87.62762711, 'Private room', 600, 3, 0, None, None, 33, 361),
#  (7458, 29850409, 'Subleasing a shared room or private room!', 224500891, 'Areeba', None, 'Near West Side', 41.86778628, -87.66101085, 'Shared room', 10, 1, 0, None, None, 1, 363),
#  (7463, 29857319, 'Chicago - Lincoln Park Mansion - Luxury', 8906491, 'Alex', None, 'Lincoln Park', 41.92018944, -87.64360456, 'Entire home/apt', 1500, 3, 0, None, None, 1, 173),
#  (7478, 29885798, 'Apartment at Wrigleyville', 34697612, 'Harry', None, 'Lake view', 41.94937885, -87.65758433, 'Entire home/apt', 700, 2, 0, None, None, 2, 318),
#  (7486, 29898010, 'Luxury Modern Wicker Park Mansion 6+beds 4.5bth', 61786359, 'Paul', None, 'West Town', 41.90465367, -87.6770626, 'Entire home/apt', 1000, 3, 0, None, None, 1, 188),
#  (7490, 29899120, 'Secluded Home ??? Lincoln Park  w/ Jacuzzi & Parking', 224822446, 'Jonathan', None, 'Lincoln Park', 41.926984999999995, -87.67015397, 'Entire home/apt', 399, 2, 0, None, None, 1, 358),
#  (7500, 29904570, 'Chicago Lake Shore Reserve', 10159376, 'Bing', None, 'Rogers Park', 42.01774627, -87.6668875, 'Entire home/apt', 495, 2, 0, None, None, 1, 148),
#  (7529, 29929401, 'Spacious 4BR Steps from Sox Park', 225031771, 'Margarita', None, 'Bridgeport', 41.82704745, -87.64058742, 'Entire home/apt', 325, 2, 0, None, None, 1, 174),
#  (7535, 29946473, 'BEAUTIFUL, COMFORTABLE ROOM WITH FREE PARKING', 55976787, 'Natalia', None, 'Near West Side', 41.88000188, -87.63949593, 'Private room', 10, 1, 0, None, None, 34, 360),
#  (7543, 29949126, 'Incredible Views! Luxury 2b/2b in the Loop.', 182280566, 'Jim', None, 'L??p', 41.88440992, -87.6263858, 'Entire home/apt', 380, 2, 0, None, None, 1, 365),
#  (7560, 29967259, 'CENTRAL LOFT ROOM WITH 2 BEDS & FREE PARKING', 55976787, 'Natalia', None, 'Near West Side', 41.87884039, -87.63873989, 'Private room', 10, 1, 0, None, None, 34, 74),
#  (7561, 29967880, 'DOWNTOWN STYLISH ROOM WITH EARLY CHECK-IN, PARKING', 55976787, 'Natalia', None, 'L??p', 41.88050197, -87.63823969, 'Private room', 10, 1, 0, None, None, 34, 355),
#  (7571, 29985217, 'Massive 2-Story Home ??? Lincoln Park w/ Balcony', 136116380, 'Michael', None, 'Lincoln Park', 41.9206648, -87.65645415, 'Entire home/apt', 399, 2, 0, None, None, 1, 358),
#  (7579, 30014242, 'BEAUTIFUL DOWNTOWN ROOM & PARKING, 7 MIN TO WILLIS', 55976787, 'Natalia', None, 'Near West Side', 41.87934962, -87.63877037, 'Private room', 10, 1, 0, None, None, 34, 356),
#  (7582, 30016223, 'PERFECT ROOM TO SEE CHICAGO, FREE PARKING', 55976787, 'Natalia', None, 'Near West Side', 41.87985066, -87.64334834, 'Private room', 10, 1, 0, None, None, 34, 362),
#  (7587, 30043302, '5 BR Home in Best Area Walk to Nightlife, Mag Mile', 41862889, 'Inna', None, 'Near North Side', 41.90907099, -87.63642824, 'Entire home/apt', 499, 1, 0, None, None, 6, 337),
#  (7589, 30045293, 'New! HGTV Featured 4br in Lincoln Park', 143825988, 'Reserve', None, 'Lincoln Park', 41.92839821, -87.65125709, 'Entire home/apt', 999, 2, 0, None, None, 33, 185)]

# %% [markdown]
# #### TASK 2.6: Checking the ```minimum_nights``` column

# %%
# %%sql
# -- Check if there's any missing data in minimum_nights column
# SELECT *
# FROM Listings
# WHERE minimum_nights IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- Check if there's irregularities in minimum_nights column
# SELECT *
# FROM Listings
# WHERE minimum_nights > 365 OR minimum_nights < 0;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %% [markdown]
# #### TASK 2.7: Checking the ```availability_365``` column

# %%
# %%sql
# -- Check if there's any missing data in availability_365 column
# SELECT *
# FROM Listings
# WHERE availability_365 IS NULL;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- Check if there's irregularities in availability_365 column
# SELECT *
# FROM Listings
# WHERE availability_365 > 365 OR availability_365 < 0;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %% [markdown]
# ### TASK 3: DATA CURATION
# ##### Description: Now that the data is much cleaner than before, we would like to create separate tables based on the original table. That way we can better organize the information contained in the original table. In order to do so, we need to make sure that our newly created tables follow a well-structured schema where the tables are connected to one another by specific columns. In what follows, we will create five new tables from the original table: the Listing, Host, Location, Review, and Listing_details tables. These tables are organized around the basic semantic units identified in the original dataset and can be joined back together with proper keys when needed.

# %% [markdown]
# #### TASK 3.1: Creating the ```Listing``` table

# %%
# %%sql
# -- Create Listing table
# CREATE TABLE Listing AS
#     SELECT id, name, host_id
#     FROM Listings;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- View the first ten instances of the newly created table
# SELECT *
# FROM Listing
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(2384, 'Hyde Park - Walk to UChicago/Theological Seminary', 2613),
#  (6715, 'Lincoln Park Oasis - Unit 2 ONLY', 15365),
#  (7126, 'Tiny Studio Apartment 94 Walk Score', 17928),
#  (9811, "Barbara's Hideaway - Old Town", 33004),
#  (10610, '3 Comforts of Cooperative Living', 2140),
#  (10945, 'The Biddle House #1', 33004),
#  (12068, 'Chicago GOLD COAST 1 Bedroom Condo', 40731),
#  (12140, 'Lincoln Park Guest House', 46734),
#  (22362, 'Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ', 85811),
#  (22651, 'beautifully furnished 3 bed/1bath 1', 87231)]

# %% [markdown]
# #### TASK 3.2: Creating the ```Host``` table

# %%
# %%sql
# -- Create Host table
# CREATE TABLE Host AS
#     SELECT host_id, calculated_host_listings_count
#     FROM Listings
#     GROUP BY host_id, calculated_host_listings_count;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- View the first ten instances of the newly created table
# SELECT *
# FROM Host
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(2140, 5),
#  (2153, 1),
#  (2613, 1),
#  (2745, 1),
#  (3908, 1),
#  (4434, 5),
#  (6162, 1),
#  (9301, 1),
#  (11278, 2),
#  (15365, 2)]

# %% [markdown]
# #### TASK 3.3: Creating the ```Location``` table

# %%
# %%sql
# -- Create Location table
# CREATE TABLE Location AS
#     SELECT id, longitude, latitude, neighbourhood, neighbourhood_group
#     FROM Listings;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- View the first ten instances of the newly created table
# SELECT *
# FROM Location
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(2384, -87.58670891, 41.7888649, 'hyde park', None),
#  (6715, -87.66009125, 41.92926222, 'OHARE', None),
#  (7126, -87.68182159999999, 41.90289494, 'West Town', None),
#  (9811, -87.63787944, 41.91768924, 'Lincoln Park', None),
#  (10610, -87.59194894, 41.79708495, 'hyde park', None),
#  (10945, -87.63999816, 41.91182685, 'Lincoln Park', None),
#  (12068, -87.63320022, 41.904520899999994, 'Near North Side', None),
#  (12140, -87.64950966, 41.92335308, 'Lincoln Park', None),
#  (22362, -87.66041074, 41.89616805, 'West Town', None),
#  (22651, -87.65790583, 41.94910517, 'Lake view', None)]

# %% [markdown]
# #### TASK 3.4: Creating the ```Review``` table

# %%
# %%sql
# -- Create Review table
# CREATE TABLE Review AS
#     SELECT id, number_of_reviews, reviews_per_month, last_review
#     FROM Listings;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- View the first ten instances of the newly created table
# SELECT *
# FROM Review
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(2384, 137, 2.92, '11/12/18'),
#  (6715, 93, 0.81, '8/12/18'),
#  (7126, 321, 2.81, '10/29/18'),
#  (9811, 33, 0.59, '10/14/18'),
#  (10610, 31, 0.63, '7/29/18'),
#  (10945, 9, 0.16, '11/5/18'),
#  (12068, 8, 0.18, '10/24/17'),
#  (12140, 4, 0.1, '10/17/18'),
#  (22362, 9, 0.15, '10/12/14'),
#  (22651, 174, 1.69, '10/21/18')]

# %% [markdown]
# #### TASK 3.5: Creating the ```Listing_details``` table

# %%
# %%sql
# -- Create Listing_details table
# CREATE TABLE Listing_details AS
#     SELECT id, room_type, minimum_nights, availability_365, price
#     FROM Listings;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# []

# %%
# %%sql
# -- View the first ten instances of the newly created table
# SELECT *
# FROM Listing_details
# LIMIT 10;
# Out:
#  * @airbnb2.db
#  * sqlite:///airbnb2.db
# Done.
# [(2384, 'Private room', 2, 163, 50),
#  (6715, 'Entire home/apt', 4, 303, 255),
#  (7126, 'Entire home/apt', 2, 362, 80),
#  (9811, 'Entire home/apt', 3, 350, 150),
#  (10610, 'Private room', 2, 179, 35),
#  (10945, 'Entire home/apt', 3, 357, 215),
#  (12068, 'Entire home/apt', 165, 303, 99),
#  (12140, 'Private room', 2, 169, 289),
#  (22362, 'Entire home/apt', 60, 280, 99),
#  (22651, 'Entire home/apt', 1, 71, 185)]

# %% [markdown]
# ##### Congratulations, you've completed this tutorial! We hope you have mastered the basic skills for working with SQLite in Python. Happy learning!
